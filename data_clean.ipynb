# %%
# Import libraries
import pandas as pd
import numpy as np

# %%
# Read in data
# oakland df
oakland_1 = pd.read_csv('data/Oakland_1.csv')
oakland_2 = pd.read_csv('data/Oakland_2.csv')

# hayward
hayward_1 = pd.read_csv('data/Hayward_1.csv')
hayward_2 = pd.read_csv('data/Hayward_2.csv')

# moffett
moffett_1 = pd.read_csv('data/Moffett_1.csv')
moffett_2 = pd.read_csv('data/Moffett_2.csv')
# Out:
# /opt/python/3.7.13/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3553: DtypeWarning: Columns (3,21,27,28,29,30,31,32,33,34,37,38,43,44,49,51,53,54,56,57,59,60,61,62,64,78,83,96,111,112,114,115,118,120) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /opt/python/3.7.13/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3553: DtypeWarning: Columns (21,27,28,29,30,31,32,37,38,43,44,49,50,54,57,59,60,61,64,115,116,118,120,123) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /opt/python/3.7.13/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3553: DtypeWarning: Columns (21,27,28,29,31,43,44,53,59,60,62,64,70,72,78,83,89) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ...

# %%
pd.set_option("display.max.columns", None)

# Check out data
oakland_1.head(1)
# Out:
#        STATION                 DATE REPORT_TYPE SOURCE  AWND  BackupDirection  \
# 0  72493023230  2004-01-01T00:00:00       NSRDB      9   NaN              NaN
#
#    BackupDistance  BackupDistanceUnit  BackupElements  BackupElevation  \
# 0             NaN                 NaN             NaN              NaN
#
#    BackupElevationUnit  BackupEquipment  BackupLatitude  BackupLongitude  \
# 0                  NaN              NaN             NaN              NaN
#
#    BackupName  CDSD  CLDD  DSNW  DYHF  DYTS  DailyAverageDewPointTemperature  \
# 0         NaN   NaN   NaN   NaN   NaN   NaN                              NaN
#
#   DailyAverageDryBulbTemperature  DailyAverageRelativeHumidity  \
# 0                            NaN                           NaN
#
#    DailyAverageSeaLevelPressure  DailyAverageStationPressure  \
# 0                           NaN                          NaN
#
#    DailyAverageWetBulbTemperature  DailyAverageWindSpeed  \
# ...

# %%
oakland_2.head(1)
# Out:
#        STATION                 DATE REPORT_TYPE  SOURCE  AWND  \
# 0  72493023230  2014-01-01T00:53:00       FM-15       7   NaN
#
#    BackupDirection  BackupDistance  BackupDistanceUnit  BackupElements  \
# 0              NaN             NaN                 NaN             NaN
#
#    BackupElevation  BackupElevationUnit  BackupEquipment  BackupLatitude  \
# 0              NaN                  NaN              NaN             NaN
#
#    BackupLongitude  BackupName  CDSD  CLDD  DSNW  DYHF  DYTS  \
# 0              NaN         NaN   NaN   NaN   NaN   NaN   NaN
#
#    DailyAverageDewPointTemperature DailyAverageDryBulbTemperature  \
# 0                              NaN                            NaN
#
#    DailyAverageRelativeHumidity  DailyAverageSeaLevelPressure  \
# 0                           NaN                           NaN
#
#    DailyAverageStationPressure  DailyAverageWetBulbTemperature  \
# 0                          NaN                             NaN
#
# ...

# %%
# Concatanate dataframes into one
oakland = pd.concat([oakland_1, oakland_2], ignore_index = True, axis = 0)
hayward = pd.concat([hayward_1, hayward_2], ignore_index = True, axis = 0)
moffett = pd.concat([moffett_1, moffett_2], ignore_index = True, axis = 0)

# Select for Station, Date, DailyMaximumDryBulbTemperature
oakland = oakland[['STATION','DATE','DailyMaximumDryBulbTemperature']]
hayward = hayward[['STATION','DATE','DailyMaximumDryBulbTemperature']]
moffett = moffett[['STATION','DATE','DailyMaximumDryBulbTemperature']]

# %%
# Rename 'DailyMaximumDryBulbTemperature' to max_temp
oakland = oakland.rename(columns = {'DailyMaximumDryBulbTemperature':'max_temp'})
hayward = hayward.rename(columns = {'DailyMaximumDryBulbTemperature':'max_temp'})
moffett = moffett.rename(columns = {'DailyMaximumDryBulbTemperature':'max_temp'})

# Clean names
# Simplify column names by replacing spaces and no capitilization
oakland.columns = (oakland.columns
                  .str.lower()
                  .str.replace(' ','_')
                )
hayward.columns = (hayward.columns
                  .str.lower()
                  .str.replace(' ','_')
                )
moffett.columns = (moffett.columns
                  .str.lower()
                  .str.replace(' ','_')
                )

# %%
# Change date to datetime
oakland['date'] = pd.to_datetime(oakland['date']).dt.date
hayward['date'] = pd.to_datetime(hayward['date']).dt.date
moffett['date'] = pd.to_datetime(moffett['date']).dt.date

# %%
# Remove rows with NA in max_temp
oakland = oakland.dropna()
hayward = hayward.dropna()
moffett = moffett.dropna()

# %% [markdown]
# Check cleaned data frames

# %%
# oakland.head(3)
oakland.dtypes
# Out:
# station      int64
# date        object
# max_temp    object
# dtype: object

# %%
hayward.head(3)
# Out:
#         station        date  max_temp
# 9   72585093228  2010-07-31      71.0
# 39  72585093228  2010-08-01      73.0
# 71  72585093228  2010-08-02      72.0

# %%
moffett.head(3)
# Out:
#         station        date max_temp
# 24  74509023244  2004-01-01     55.0
# 49  74509023244  2004-01-02     53.0
# 74  74509023244  2004-01-03     50.0

# %% [markdown]
# Save cleaned data frames as csvs.

# %%
oakland.to_csv('oakland_temp.csv')
hayward.to_csv('hayward_temp.csv')
moffett.to_csv('moffett_temp.csv')
